# %%
import cv2 # importing cv2 library

cam = cv2.VideoCapture(0)

count = 0

while True:
    ret, img = cam.read()

    cv2.imshow("Test", img)

    if not ret:
        break

    k=cv2.waitKey(1)

    if k%256==27:
        #For Esc key
        print("Close")
        break
    elif k%256==32:
        #For Space key

        print("Image "+str(count)+"saved")
        file='C:/Users/Atharva Kasodekar/Desktop/Projects/Image_Authentication/code'+str(count)+'.jpg'
        cv2.imwrite(file, img)
        count +=1

cam.release
cv2.destroyAllWindows
# Out:
# Image 0saved
# Image 1saved

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import skimage
from skimage import filters
# %matplotlib inline
from skimage.io import imread, imshow

# %%
image1 = imread('code0.jpg')
imshow(image1);

# %%
image2 = imread('code0.jpg', as_gray=True)
imshow(image2);

# %%
print(image1.shape)
print(image2.shape)
# Out:
# (480, 640, 3)
# (480, 640)

# %%
print(image1.size)
print(image2.size)
# Out:
# 921600
# 307200

# %%
pixel_feat1 = np.reshape(image2, (480*640))
pixel_feat1
# Out:
# array([0.99438902, 0.99438902, 0.99438902, ..., 0.40942745, 0.4214749 ,
#        0.42931804])

# %%
pixel_feat2 = np.reshape(image1, (480*640*3))
pixel_feat2
# Out:
# array([255, 253, 255, ..., 118, 108,  99], dtype=uint8)

# %%
from skimage import feature
# prewitt kernel
pre_hor = skimage.filters.prewitt_h(image2)
pre_ver = skimage.filters.prewitt_v(image2)

# Sobel Kernel
ed_sobel = filters.sobel(image2)

#canny algorithm
can = feature.canny(image2)

imshow(pre_ver, cmap='gray');

# %%
imshow(pre_hor, cmap='gray');

# %%
imshow(ed_sobel, cmap='gray');

# %%
imshow(can, cmap='gray')

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image2)

#Plotting the Image and the Histogram of gray values
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
# Out:
# Text(0.5, 1.0, 'histogram of gray values')

# %%
from PIL import Image
from numpy import array
im_1 = Image.open(r"code0.jpg")
ar = array(im_1)
ar
# Out:
# array([[[255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255],
#         ...,
#         [152, 148, 139],
#         [153, 149, 140],
#         [154, 150, 141]],
#
#        [[255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255],
#         ...,
#         [152, 148, 139],
#         [153, 149, 140],
#         [153, 150, 141]],
#
#        [[255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255],
#         ...,
#         [151, 149, 137],
#         [152, 149, 140],
#         [152, 149, 140]],
#
#        ...,
#
#        [[159, 156, 147],
#         [159, 157, 145],
#         [160, 158, 146],
#         ...,
#         [112, 104,  93],
#         [116, 108,  97],
#         [118, 110,  99]],
#
#        [[158, 155, 146],
#         [157, 154, 145],
#         [159, 157, 145],
#         ...,
#         [113, 103,  93],
#         [116, 106,  96],
#         [118, 108,  98]],
#
#        [[159, 156, 147],
#         [157, 154, 145],
#         [158, 156, 144],
#         ...,
#         [113, 103,  93],
#         [116, 106,  97],
#         [118, 108,  99]]], dtype=uint8)
